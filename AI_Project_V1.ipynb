# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishah-Naushad/YoloV8-Custom-Data-Training/blob/main/AI_Project_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Mounting Google Drive and Setting up root directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT_DIR = '/content/drive/MyDrive/AI_Project/V1'

# %% [markdown]
# #Training Dataset

# %%
import os

from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "train.yaml"), epochs=100)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
# ...

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/drive/MyDrive/AI_Project/V1'

# %% [markdown]
# #Testing Model

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/AI_Project/V1/runs/detect/train7/weights/best.pt" source="/content/drive/MyDrive/AI_Project/V1/test/images" save=True
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_1.jpg: 640x640 2 tables, 10.1ms
# image 2/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_10.jpg: 640x640 1 table, 7.4ms
# image 3/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_100.jpg: 640x640 1 table, 7.3ms
# image 4/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_100_affine_translation.jpg: 640x640 1 table, 7.3ms
# image 5/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_100_brightness.jpg: 640x640 1 table, 7.3ms
# image 6/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_100_gaussianblur.jpg: 640x640 1 table, 7.3ms
# image 7/100 /content/drive/MyDrive/AI_Project/V1/test/images/Invoice_100_horizontallyflip.jpg: 640x640 2 tables, 7.3ms
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/AI_Project/V1'
